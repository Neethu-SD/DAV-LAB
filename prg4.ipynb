# %%
import pandas as pd

df = pd.read_csv(r"C:/Users/user/Downloads/archive (7)/Expanded_data_with_more_features.csv")

df
# Out:
#        Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType  \
# 0               0  female         NaN   bachelor's degree      standard
# 1               1  female     group C        some college      standard
# 2               2  female     group B     master's degree      standard
# 3               3    male     group A  associate's degree  free/reduced
# 4               4    male     group C        some college      standard
# ...           ...     ...         ...                 ...           ...
# 30636         816  female     group D         high school      standard
# 30637         890    male     group E         high school      standard
# 30638         911  female         NaN         high school  free/reduced
# 30639         934  female     group D  associate's degree      standard
# 30640         960    male     group B        some college      standard
#
#         TestPrep ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings  \
# ...

# %%
print(df.isnull())
# Out:
#        Unnamed: 0  Gender  EthnicGroup  ParentEduc  LunchType  TestPrep  \
# 0           False   False         True       False      False     False
# 1           False   False        False       False      False      True
# 2           False   False        False       False      False     False
# 3           False   False        False       False      False     False
# 4           False   False        False       False      False     False
# ...           ...     ...          ...         ...        ...       ...
# 30636       False   False        False       False      False     False
# 30637       False   False        False       False      False     False
# 30638       False   False         True       False      False     False
# 30639       False   False        False       False      False     False
# 30640       False   False        False       False      False     False
#
#        ParentMaritalStatus  PracticeSport  IsFirstChild  NrSiblings  \
# ...

# %%
print(df.isnull().sum())
# Out:
# Unnamed: 0                0
# Gender                    0
# EthnicGroup            1840
# ParentEduc             1845
# LunchType                 0
# TestPrep               1830
# ParentMaritalStatus    1190
# PracticeSport           631
# IsFirstChild            904
# NrSiblings             1572
# TransportMeans         3134
# WklyStudyHours          955
# MathScore                 0
# ReadingScore              0
# WritingScore              0
# dtype: int64

# %%
df["NrSiblings"] = df["NrSiblings"].fillna(df["NrSiblings"].mean())
print(df)
# Out:
#        Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType  \
# 0               0  female         NaN   bachelor's degree      standard
# 1               1  female     group C        some college      standard
# 2               2  female     group B     master's degree      standard
# 3               3    male     group A  associate's degree  free/reduced
# 4               4    male     group C        some college      standard
# ...           ...     ...         ...                 ...           ...
# 30636         816  female     group D         high school      standard
# 30637         890    male     group E         high school      standard
# 30638         911  female         NaN         high school  free/reduced
# 30639         934  female     group D  associate's degree      standard
# 30640         960    male     group B        some college      standard
#
#         TestPrep ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings  \
# ...

# %%
print("mean:",df["NrSiblings"].mean())
# Out:
# mean: 2.1458942516082424

# %%
df['NrSiblings'] = df['NrSiblings'].fillna(df['NrSiblings'].median())
print(df)
# Out:
#        Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType  \
# 0               0  female         NaN   bachelor's degree      standard
# 1               1  female     group C        some college      standard
# 2               2  female     group B     master's degree      standard
# 3               3    male     group A  associate's degree  free/reduced
# 4               4    male     group C        some college      standard
# ...           ...     ...         ...                 ...           ...
# 30636         816  female     group D         high school      standard
# 30637         890    male     group E         high school      standard
# 30638         911  female         NaN         high school  free/reduced
# 30639         934  female     group D  associate's degree      standard
# 30640         960    male     group B        some college      standard
#
#         TestPrep ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings  \
# ...

# %%
print("median:",df["NrSiblings"].median())
# Out:
# median: 2.0

# %%
print("Before Forward Fill:")
print(df['EthnicGroup'])

df['EthnicGroup'] = df['EthnicGroup'].ffill()

print("\nAfter Forward Fill:")
print(df['EthnicGroup'])
# Out:
# Before Forward Fill:
# 0            NaN
# 1        group C
# 2        group B
# 3        group A
# 4        group C
#           ...
# 30636    group D
# 30637    group E
# 30638        NaN
# 30639    group D
# 30640    group B
# Name: EthnicGroup, Length: 30641, dtype: object
#
# After Forward Fill:
# 0            NaN
# 1        group C
# 2        group B
# 3        group A
# 4        group C
#           ...
# 30636    group D
# 30637    group E
# 30638    group E
# 30639    group D
# 30640    group B
# Name: EthnicGroup, Length: 30641, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()

df['Gender_Encoded'] = encoder.fit_transform(df['Gender'])

print(df)
print(encoder.classes_)
# Out:
#        Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType  \
# 0               0  female         NaN   bachelor's degree      standard
# 1               1  female     group C        some college      standard
# 2               2  female     group B     master's degree      standard
# 3               3    male     group A  associate's degree  free/reduced
# 4               4    male     group C        some college      standard
# ...           ...     ...         ...                 ...           ...
# 30636         816  female     group D         high school      standard
# 30637         890    male     group E         high school      standard
# 30638         911  female     group E         high school  free/reduced
# 30639         934  female     group D  associate's degree      standard
# 30640         960    male     group B        some college      standard
#
#         TestPrep ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings  \
# ...

# %%
encoder = LabelEncoder()

df['EthnicGroup_Encoded'] = encoder.fit_transform(df['EthnicGroup'])

print(df)
print(encoder.classes_)
# Out:
#        Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType  \
# 0               0  female         NaN   bachelor's degree      standard
# 1               1  female     group C        some college      standard
# 2               2  female     group B     master's degree      standard
# 3               3    male     group A  associate's degree  free/reduced
# 4               4    male     group C        some college      standard
# ...           ...     ...         ...                 ...           ...
# 30636         816  female     group D         high school      standard
# 30637         890    male     group E         high school      standard
# 30638         911  female     group E         high school  free/reduced
# 30639         934  female     group D  associate's degree      standard
# 30640         960    male     group B        some college      standard
#
#         TestPrep ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings  \
# ...

# %%
encoder = LabelEncoder()

df['EthnicGroup_Encoded'] = encoder.fit_transform(df['EthnicGroup'])

print(df)
print(encoder.classes_)
# Out:
#        Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType  \
# 0               0  female         NaN   bachelor's degree      standard
# 1               1  female     group C        some college      standard
# 2               2  female     group B     master's degree      standard
# 3               3    male     group A  associate's degree  free/reduced
# 4               4    male     group C        some college      standard
# ...           ...     ...         ...                 ...           ...
# 30636         816  female     group D         high school      standard
# 30637         890    male     group E         high school      standard
# 30638         911  female     group E         high school  free/reduced
# 30639         934  female     group D  associate's degree      standard
# 30640         960    male     group B        some college      standard
#
#         TestPrep ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings  \
# ...

# %%
import pandas as pd

encoded_df = pd.get_dummies(df, columns=['Gender'])

print(encoded_df)
# Out:
#        Unnamed: 0 EthnicGroup          ParentEduc     LunchType   TestPrep  \
# 0               0         NaN   bachelor's degree      standard       none
# 1               1     group C        some college      standard        NaN
# 2               2     group B     master's degree      standard       none
# 3               3     group A  associate's degree  free/reduced       none
# 4               4     group C        some college      standard       none
# ...           ...         ...                 ...           ...        ...
# 30636         816     group D         high school      standard       none
# 30637         890     group E         high school      standard       none
# 30638         911     group E         high school  free/reduced  completed
# 30639         934     group D  associate's degree      standard  completed
# 30640         960     group B        some college      standard       none
#
#       ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings  \
# ...

# %%
encoded_df = pd.get_dummies(
    df,
    columns=['Gender'],
    dtype=int
)
print(encoded_df)
# Out:
#        Unnamed: 0 EthnicGroup          ParentEduc     LunchType   TestPrep  \
# 0               0         NaN   bachelor's degree      standard       none
# 1               1     group C        some college      standard        NaN
# 2               2     group B     master's degree      standard       none
# 3               3     group A  associate's degree  free/reduced       none
# 4               4     group C        some college      standard       none
# ...           ...         ...                 ...           ...        ...
# 30636         816     group D         high school      standard       none
# 30637         890     group E         high school      standard       none
# 30638         911     group E         high school  free/reduced  completed
# 30639         934     group D  associate's degree      standard  completed
# 30640         960     group B        some college      standard       none
#
#       ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings  \
# ...
